# %% [markdown]
# This note book contains the scripts for preprocessing financil data from a video, converting them from video to frames and then sending them to VERTEX GEMINI API for extracting data. using offcial Vertex SDK for video uploading.

# %%
# # only run if you want to To download video from s3 or any downloadable link convert video into frames and save it into a folder. read the last 2 instruction paras
# import cv2
# import os
# import urllib.request

# def download_video(url, local_path):
#     try:
#         urllib.request.urlretrieve(url, local_path)
#         print(f"Video downloaded from {url} to: {local_path}")
#         return True
#     except Exception as e:
#         print(f"Error downloading video: {e}")
#         return False

# def save_frames_from_video(video_path, output_folder, frame_interval=1):
#     if not os.path.exists(output_folder):
#         os.makedirs(output_folder)

#     video = cv2.VideoCapture(video_path)
#     if not video.isOpened():
#         print("Error: Could not open video.")
#         return

#     frame_count = 0
#     while True:
#         success, frame = video.read()
#         if not success:
#             break

#         if frame_count % frame_interval == 0:
#             frame_file = os.path.join(output_folder, f"frame_{frame_count}.jpg")
#             cv2.imwrite(frame_file, frame)

#         frame_count += 1

#     video.release()
#     print(f"Total frames saved: {frame_count}")

# # System prompt for video URL
# video_url = input("Enter the URL of the video to download: ")
# local_video_path = "downloaded_video.mp4"  # Local path to save the downloaded video

# # User prompt for frame extraction interval
# frame_interval = int(input("Enter the frame extraction interval (e.g., 1 for every frame, 10 for every 10th frame, etc.): "))

# # Download video from the provided URL
# if download_video(video_url, local_video_path):
#     # Process and save frames from the downloaded video
#     output_directory = "./2Day frames"  # Replace with your desired output folder
#     save_frames_from_video(local_video_path, output_directory)
    
# # # Video URL
# # video_url = "https://0-source-principal-administrative.s3.amazonaws.com/0-public-data/SPX_2D.mp4"
# # local_video_path = "2day Data.mp4"  # Local path to save the downloaded video

# # Download video from the provided URL
# if download_video(video_url, local_video_path):
#     # Process and save frames from the downloaded video
#     output_directory = "./2Day frames"  # Replace with your desired output folder
#     save_frames_from_video(local_video_path, output_directory)

# %%
import cv2
import os
import urllib.request

def download_video(url, local_path):
    if os.path.exists(local_path):
        print(f"Video already exists at: {local_path}")
        return True

    try:
        urllib.request.urlretrieve(url, local_path)
        print(f"Video downloaded from {url} to: {local_path}")
        return True
    except Exception as e:
        print(f"Error downloading video: {e}")
        return False

def save_frames_from_video(video_path, output_folder, frame_interval=1):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    video = cv2.VideoCapture(video_path)
    if not video.isOpened():
        print("Error: Could not open video.")
        return

    frame_count = 0
    while True:
        success, frame = video.read()
        if not success:
            break

        if frame_count % frame_interval == 0:
            frame_file = os.path.join(output_folder, f"frame_{frame_count}.jpg")
            cv2.imwrite(frame_file, frame)

        frame_count += 1

    video.release()
    print(f"Total frames saved: {frame_count}")

# System prompt for video URL
video_url = input("Enter the URL of the video to download: ")
local_video_path = "downloaded_video.mp4"  # Local path to save the downloaded video

# User prompt for frame extraction interval
frame_interval = int(input("Enter the frame extraction interval (e.g., 1 for every frame, 10 for every 10th frame, etc.): "))

# Download video from the provided URL if not already downloaded
if download_video(video_url, local_video_path):
    # Process and save frames from the downloaded video
    output_directory = "./2Day frames"  # Replace with your desired output folder
    save_frames_from_video(local_video_path, output_directory, frame_interval)
# Out:
# Enter the URL of the video to download: https://0-source-principal-administrative.s3.amazonaws.com/0-public-data/SPX_2D.mp4
# Enter the frame extraction interval (e.g., 1 for every frame, 10 for every 10th frame, etc.): 1
# Video already exists at: downloaded_video.mp4
# Total frames saved: 3499

# %%
# !pip install pytesseract

# %%
# import pytesseract
# pytesseract.pytesseract.tesseract_cmd = (
#     r'/usr/bin/tesseract'
# )

# %%
# import os
# from PIL import Image
# import pytesseract


# # Path to the folder containing images
# folder_path = '2Day frames'

# # This function uses Tesseract to extract text from a specified region in an image
# def extract_date_from_image(image_path, region):
#     with Image.open(image_path) as img:
#         cropped_img = img.crop(region)
#         text = pytesseract.image_to_string(cropped_img, lang='eng', config='--psm 6')
#         return text.strip()


# # Define the region where the date is located
# date_region = (142, 50, 267, 75)

# # Get all image file paths
# image_paths = [os.path.join(folder_path, filename) for filename in os.listdir(folder_path) if filename.endswith(('.jpg', '.png'))]

# # Create a dictionary to group images by date
# date_groups = {}

# # Process each image
# for image_path in image_paths:
#     date_text = extract_date_from_image(image_path, date_region)
#     if date_text not in date_groups:
#         date_groups[date_text] = []
#     date_groups[date_text].append(image_path)

# # Now you have a dictionary where the key is the date and the value is a list of image paths with that date
# for date, images in date_groups.items():
#     print(f"Date: {date}, Images: {images}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-771eeea675e3> in <module>
#      26 # Process each image
#      27 for image_path in image_paths:
# ---> 28     date_text = extract_date_from_image(image_path, date_region)
#      29     if date_text not in date_groups:
#      30         date_groups[date_text] = []
#
# <ipython-input-7-771eeea675e3> in extract_date_from_image(image_path, region)
#      11     with Image.open(image_path) as img:
#      12         cropped_img = img.crop(region)
# ---> 13         text = pytesseract.image_to_string(cropped_img, lang='eng', config='--psm 6')
#      14         return text.strip()
#      15
#
# ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py in image_to_string(image, lang, config, nice, output_type, timeout)
#     421     args = [image, 'txt', lang, config, nice, timeout]
#     422
# --> 423     return {
#     424         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     425         Output.DICT: lambda: {'text': run_and_get_output(*args)},
#
# ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py in <lambda>()
#     424         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     425         Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 426         Output.STRING: lambda: run_and_get_output(*args),
#     427     }[output_type]()
#     428
#
# ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     291             if return_bytes:
#     292                 return output_file.read()
# --> 293             return output_file.read().decode(DEFAULT_ENCODING)
#     294
#     295
#
# ~\anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py in save(image)
#     200             yield f.name, input_file_name
#     201     finally:
# --> 202         cleanup(f.name)
#     203
#     204
#
# ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py in cleanup(temp_name)
#     159 def cleanup(temp_name):
#     160     """Tries to remove temp files by filename wildcard path."""
# --> 161     for filename in iglob(f'{temp_name}*' if temp_name else temp_name):
#     162         try:
#     163             remove(filename)
#
# ~\anaconda3\lib\glob.py in _iglob(pathname, recursive, dironly)
#      72         glob_in_dir = _glob0
#      73     for dirname in dirs:
# ---> 74         for name in glob_in_dir(dirname, basename, dironly):
#      75             yield os.path.join(dirname, name)
#      76
#
# ~\anaconda3\lib\glob.py in _glob1(dirname, pattern, dironly)
#      80
#      81 def _glob1(dirname, pattern, dironly):
# ---> 82     names = list(_iterdir(dirname, dironly))
#      83     if not _ishidden(pattern):
#      84         names = (x for x in names if not _ishidden(x))
#
# ~\anaconda3\lib\glob.py in _iterdir(dirname, dironly)
#     123         with os.scandir(dirname) as it:
#     124             for entry in it:
# --> 125                 try:
#     126                     if not dironly or entry.is_dir():
#     127                         yield entry.name
#
# KeyboardInterrupt:

# %%
#ABOVE CODE WITH 10 MIN TIMEOUT, USE THIS BLOCK IF PROCESSING IS SLOW ABOVE
import os
from PIL import Image
import pytesseract
import time

# Path to the folder containing images
folder_path = '2Day frames'

# This function uses Tesseract to extract text from a specified region in an image
def extract_date_from_image(image_path, region):
    try:
        with Image.open(image_path) as img:
            cropped_img = img.crop(region)
            text = pytesseract.image_to_string(cropped_img, lang='eng', config='--psm 6')
            return text.strip()
    except Exception as e:
        print(f"Error processing image {image_path}: {e}")
        return None

# Define the region where the date is located
date_region = (142, 50, 267, 75)

# Get all image file paths
image_paths = [os.path.join(folder_path, filename) for filename in os.listdir(folder_path) if filename.endswith(('.jpg', '.png'))]

# Create a dictionary to group images by date
date_groups = {}

# Set a timeout (in seconds)
timeout = 600  # 10 minutes

# Process each image
start_time = time.time()
for image_path in image_paths:
    elapsed_time = time.time() - start_time
    if elapsed_time > timeout:
        print(f"Timeout reached. Exiting.")
        break

    date_text = extract_date_from_image(image_path, date_region)
    if date_text is not None:
        if date_text not in date_groups:
            date_groups[date_text] = []
        date_groups[date_text].append(image_path)

# Now you have a dictionary where the key is the date and the value is a list of image paths with that date
for date, images in date_groups.items():
    print(f"Date: {date}, Images: {images}")
# Out:
# Timeout reached. Exiting.
# Date: D: 12/26/22, Images: ['2Day frames\\frame_0.jpg', '2Day frames\\frame_1.jpg', '2Day frames\\frame_10.jpg', '2Day frames\\frame_100.jpg', '2Day frames\\frame_101.jpg', '2Day frames\\frame_102.jpg', '2Day frames\\frame_103.jpg', '2Day frames\\frame_104.jpg', '2Day frames\\frame_105.jpg', '2Day frames\\frame_106.jpg', '2Day frames\\frame_107.jpg', '2Day frames\\frame_108.jpg', '2Day frames\\frame_109.jpg', '2Day frames\\frame_11.jpg', '2Day frames\\frame_110.jpg', '2Day frames\\frame_111.jpg', '2Day frames\\frame_112.jpg', '2Day frames\\frame_113.jpg', '2Day frames\\frame_114.jpg', '2Day frames\\frame_115.jpg', '2Day frames\\frame_116.jpg', '2Day frames\\frame_117.jpg', '2Day frames\\frame_118.jpg', '2Day frames\\frame_119.jpg', '2Day frames
# {'D: 12/13/23'} {'2Day frames\\frame_3282.jpg'}
# {'D: 12/15/23'} {'2Day frames\\frame_3308.jpg'}
# {'D: 12/19/23'} {'2Day frames\\frame_3335.jpg'}
# {'D: 12/21/23'} {'2Day frames\\frame_3364.jpg'}
# {'D: 12/27/23'} {'2Day frames\\frame_3408.jpg'}
# {'D: 12/29/23'} {'2Day frames\\frame_3409.jpg'}
# {'D: 1/8/24'} {'2Day frames\\frame_3410.jpg'}
# {'D: 1/10/24'} {'2Day frames\\frame_3411.jpg'}
# {'D: 1/12/24'} {'2Day frames\\frame_3412.jpg'}
# {'D: 1/16/24'} {'2Day frames\\frame_3413.jpg'}
# {'D: 1/17/23'} {'2Day frames\\frame_345.jpg'}
# {'D: 1/19/23'} {'2Day frames\\frame_367.jpg'}
# {'D: 1/23/23'} {'2Day frames\\frame_389.jpg'}
# {'D: 1/25/23'} {'2Day frames\\frame_413.jpg'}
# {'D: 1/27/23'} {'2Day frames\\frame_435.jpg'}
# {'D: 1/31/23'} {'2Day frames\\frame_464.jpg'}
# {'D: 2/2/23 ¢'} {'2Day frames\\frame_487.jpg'}
# {'D: 2/2/23 | ¢'} {'2Day frames\\frame_494.jpg'}
# {'D: 2/2/23 | C'} {'2Day frames\\frame_504.jpg'}
# {'D: 2/6/23 ¢'} {'2Day frames\\frame_515.jpg'}
# {'D: 2/8/23 | C'} {'2Day frames\\frame_537.jpg'}
# {'D: 2/8/23 ¢'} {'2Day frames\\frame_543.jpg'}
# {'D: 2/10/23'} {'2Day frames\\frame_564.jpg'}

# %%
#only run to make a copy of extracted unique images to new folder
import os
import shutil

# Base directory where new folders will be created
base_directory = '2D extracted frames'  # Replace with your desired path

# Iterate over the dictionary
for date, image_path in new.items():
    # Create a valid directory name for the date
    # Replace invalid characters for folder names (like '/') with an underscore or another valid character
    folder_name = date.replace(':', '_').replace('/', '_')
    directory_path = os.path.join(base_directory)

    # Create the directory if it doesn't exist
    if not os.path.exists(directory_path):
        os.makedirs(directory_path)

    # Define the destination path for the image
    destination_path = os.path.join(directory_path, os.path.basename(image_path))

    # Copy the image to the new location
    shutil.copy(image_path, destination_path)

    print(f"Copied {image_path} to {destination_path}")
# Out:
# Copied 2Day frames\frame_0.jpg to 2D extracted frames\frame_0.jpg
# Copied 2Day frames\frame_1000.jpg to 2D extracted frames\frame_1000.jpg
# Copied 2Day frames\frame_1015.jpg to 2D extracted frames\frame_1015.jpg
# Copied 2Day frames\frame_1038.jpg to 2D extracted frames\frame_1038.jpg
# Copied 2Day frames\frame_1067.jpg to 2D extracted frames\frame_1067.jpg
# Copied 2Day frames\frame_1109.jpg to 2D extracted frames\frame_1109.jpg
# Copied 2Day frames\frame_1144.jpg to 2D extracted frames\frame_1144.jpg
# Copied 2Day frames\frame_1164.jpg to 2D extracted frames\frame_1164.jpg
# Copied 2Day frames\frame_1191.jpg to 2D extracted frames\frame_1191.jpg
# Copied 2Day frames\frame_1221.jpg to 2D extracted frames\frame_1221.jpg
# Copied 2Day frames\frame_1246.jpg to 2D extracted frames\frame_1246.jpg

# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0 in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-cloud-aiplatform) (2.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-cloud-aiplatform) (1.23.0)
# Requirement already satisfied: google-cloud-bigquery<4.0.0dev,>=1.15.0 in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-cloud-aiplatform) (3.16.0)
# Requirement already satisfied: shapely<3.0.0dev in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-cloud-aiplatform) (2.0.2)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5
#   Using cached protobuf-4.25.2-cp38-cp38-win_amd64.whl (413 kB)
# Requirement already satisfied: packaging>=14.3 in c:\users\suyash\anaconda3\lib\site-packages (from google-cloud-aiplatform) (23.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform) (0.13.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.4.1)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\suyash\anaconda3\lib\site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.31.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.5.0)
# Requirement already satisfied: google-auth<3.0dev,>=2.23.3 in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.26.2)
# Requirement already satisfied: google-resumable-media>=2.6.0 in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.7.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.62.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2; extra == "grpc" in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.60.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2; extra == "grpc" in c:\users\suyash\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.58.0)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in c:\users\suyash\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.8.1)
# Requirement already satisfied: numpy>=1.14 in c:\users\suyash\anaconda3\lib\site-packages (from shapely<3.0.0dev->google-cloud-aiplatform) (1.21.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\suyash\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\suyash\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\suyash\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\suyash\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (3.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\suyash\anaconda3\lib\site-packages (from google-auth<3.0dev,>=2.23.3->google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\suyash\anaconda3\lib\site-packages (from google-auth<3.0dev,>=2.23.3->google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (4.7.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\suyash\anaconda3\lib\site-packages (from google-auth<3.0dev,>=2.23.3->google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (4.2.4)
# Requirement already satisfied: six>=1.5 in c:\users\suyash\anaconda3\lib\site-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (1.15.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\suyash\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.23.3->google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (0.5.0)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.0
#     Uninstalling protobuf-3.20.0:
#       Successfully uninstalled protobuf-3.20.0
# Successfully installed protobuf-4.25.2

# %%
from google.cloud import aiplatform

aiplatform.init(project="crafty-ring-411412")

# %%
pip install --upgrade google-cloud-aiplatform
# Out:
# Requirement already up-to-date: google-cloud-aiplatform in c:\users\suyash\appdata\roaming\python\python38\site-packages (1.39.0)
# Requirement already satisfied, skipping upgrade: shapely<3.0.0dev in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-cloud-aiplatform) (2.0.2)
# Requirement already satisfied, skipping upgrade: proto-plus<2.0.0dev,>=1.22.0 in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-cloud-aiplatform) (1.23.0)
# Requirement already satisfied, skipping upgrade: google-cloud-bigquery<4.0.0dev,>=1.15.0 in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-cloud-aiplatform) (3.16.0)
# Requirement already satisfied, skipping upgrade: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in c:\users\suyash\anaconda3\lib\site-packages (from google-cloud-aiplatform) (4.25.2)
# Requirement already satisfied, skipping upgrade: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-cloud-aiplatform) (1.11.0)
# Requirement already satisfied, skipping upgrade: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0 in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-cloud-aiplatform) (2.15.0)
# Requirement already satisfied, skipping upgrade: google-cloud-storage<3.0.0dev,>=1.32.0 in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-cloud-aiplatform) (2.14.0)
# Requirement already satisfied, skipping upgrade: packaging>=14.3 in c:\users\suyash\anaconda3\lib\site-packages (from google-cloud-aiplatform) (23.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.14 in c:\users\suyash\anaconda3\lib\site-packages (from shapely<3.0.0dev->google-cloud-aiplatform) (1.21.0)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0dev,>=2.7.2 in c:\users\suyash\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.8.1)
# Requirement already satisfied, skipping upgrade: requests<3.0.0dev,>=2.21.0 in c:\users\suyash\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.31.0)
# Requirement already satisfied, skipping upgrade: google-resumable-media<3.0dev,>=0.6.0 in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.7.0)
# Requirement already satisfied, skipping upgrade: google-cloud-core<3.0.0dev,>=1.6.0 in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.4.1)
# Requirement already satisfied, skipping upgrade: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform) (0.13.0)
# Requirement already satisfied, skipping upgrade: google-auth<3.0.dev0,>=2.14.1 in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.26.2)
# Requirement already satisfied, skipping upgrade: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.62.0)
# Requirement already satisfied, skipping upgrade: grpcio-status<2.0.dev0,>=1.33.2; extra == "grpc" in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.60.0)
# Requirement already satisfied, skipping upgrade: grpcio<2.0dev,>=1.33.2; extra == "grpc" in c:\users\suyash\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.58.0)
# Requirement already satisfied, skipping upgrade: google-crc32c<2.0dev,>=1.0 in c:\users\suyash\appdata\roaming\python\python38\site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.5.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\users\suyash\anaconda3\lib\site-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (1.15.0)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5 in c:\users\suyash\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.10)
# Requirement already satisfied, skipping upgrade: charset-normalizer<4,>=2 in c:\users\suyash\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (3.3.2)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\suyash\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2020.6.20)
# Requirement already satisfied, skipping upgrade: urllib3<3,>=1.21.1 in c:\users\suyash\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (1.25.11)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4 in c:\users\suyash\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (4.7.2)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in c:\users\suyash\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (0.3.0)
# Requirement already satisfied, skipping upgrade: cachetools<6.0,>=2.0.0 in c:\users\suyash\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (4.2.4)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in c:\users\suyash\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (0.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install protobuf==3.20
# Out:
# Requirement already satisfied: protobuf==3.20 in c:\users\suyash\anaconda3\lib\site-packages (3.20.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from vertexai.preview.generative_models import (
    GenerationConfig,
    GenerativeModel,
    Image,
    Part,
)

import vertexai
vertexai.init(project="crafty-ring-411412", location="us-central1")

# %%
multimodal_model = GenerativeModel("gemini-pro-vision")

# %%
#Sorting the frame names and Extracting frames from the folder.
import os
import re
from vertexai.preview.generative_models import Image

def extract_number(file_name):
    # Extract the numeric part from the filename
    match = re.search(r'\d+', file_name)
    return int(match.group()) if match else 0

# Directory containing your images
directory = "./2D extracted frames"

# List all image filenames in the directory
image_filenames = [filename for filename in os.listdir(directory) if filename.endswith(".jpg")]

# Sort the image filenames by their numeric part
sorted_filenames = sorted(image_filenames, key=lambda x: extract_number(x))
print(sorted_filenames)
# Load images in sorted order
images = [Image.load_from_file(os.path.join(directory, filename)) for filename in sorted_filenames]

print(len(images))
# Out:
# ['frame_0.jpg', 'frame_133.jpg', 'frame_166.jpg', 'frame_205.jpg', 'frame_229.jpg', 'frame_254.jpg', 'frame_292.jpg', 'frame_321.jpg', 'frame_345.jpg', 'frame_367.jpg', 'frame_389.jpg', 'frame_413.jpg', 'frame_435.jpg', 'frame_464.jpg', 'frame_487.jpg', 'frame_494.jpg', 'frame_504.jpg', 'frame_515.jpg', 'frame_537.jpg', 'frame_543.jpg', 'frame_564.jpg', 'frame_586.jpg', 'frame_605.jpg', 'frame_630.jpg', 'frame_653.jpg', 'frame_678.jpg', 'frame_704.jpg', 'frame_729.jpg', 'frame_751.jpg', 'frame_770.jpg', 'frame_795.jpg', 'frame_821.jpg', 'frame_844.jpg', 'frame_875.jpg', 'frame_899.jpg', 'frame_916.jpg', 'frame_936.jpg', 'frame_955.jpg', 'frame_973.jpg', 'frame_1000.jpg', 'frame_1015.jpg', 'frame_1038.jpg', 'frame_1067.jpg', 'frame_1109.jpg', 'frame_1144.jpg', 'frame_1164.jpg', 'frame_1191.jpg', 'frame_1221.jpg', 'frame_1246.jpg', 'frame_1248.jpg', 'frame_1266.jpg', 'frame_1298.jpg', 'frame_1318.jpg', 'frame_1338.jpg', 'frame_1355.jpg', 'frame_1375.jpg', 'frame_1395.jpg', 'frame_1415.jpg', 'frame_1440.jpg', 'frame_1464.jpg', 'frame_1483.jpg', 'frame_1505.jpg', 'frame_1538.jpg', 'frame_1571.jpg', 'frame_1594.jpg', 'frame_1619.jpg', 'frame_1646.jpg', 'frame_1664.jpg', 'frame_1685.jpg', 'frame_1709.jpg', 'frame_1736.jpg', 'frame_1755.jpg', 'frame_1774.jpg', 'frame_1795.jpg', 'frame_1822.jpg', 'frame_1845.jpg', 'frame_1884.jpg', 'frame_1906.jpg', 'frame_1927.jpg', 'frame_1947.jpg', 'frame_1967.jpg', 'frame_1995.jpg', 'frame_2018.jpg', 'frame_2052.jpg', 'frame_2081.jpg', 'frame_2116.jpg', 'frame_2142.jpg', 'frame_2161.jpg', 'frame_2185.jpg', 'frame_2211.jpg', 'frame_2243.jpg', 'frame_2266.jpg', 'frame_2307.jpg', 'frame_2324.jpg', 'frame_2351.jpg', 'frame_2374.jpg', 'frame_2395.jpg', 'frame_2429.jpg', 'frame_2456.jpg', 'frame_2488.jpg', 'frame_2515.jpg', 'frame_2575.jpg', 'frame_2604.jpg', 'frame_2632.jpg', 'frame_2651.jpg', 'frame_2678.jpg', 'frame_2696.jpg', 'frame_2724.jpg', 'frame_2748.jpg', 'frame_2772.jpg', 'frame_2789.jpg', 'frame_2809.jpg', 'frame_2828.jpg', 'frame_2853.jpg', 'frame_2873.jpg', 'frame_2909.jpg', 'frame_2929.jpg', 'frame_2973.jpg', 'frame_2996.jpg', 'frame_3016.jpg', 'frame_3038.jpg', 'frame_3060.jpg', 'frame_3090.jpg', 'frame_3125.jpg', 'frame_3155.jpg', 'frame_3174.jpg', 'frame_3193.jpg', 'frame_3212.jpg', 'frame_3241.jpg', 'frame_3265.jpg', 'frame_3282.jpg', 'frame_3308.jpg', 'frame_3335.jpg', 'frame_3364.jpg', 'frame_3408.jpg', 'frame_3409.jpg', 'frame_3410.jpg', 'frame_3411.jpg', 'frame_3412.jpg', 'frame_3413.jpg']
# 140

# %%
#multiple images per request [block-1]
New = images[:15]
generation_config = GenerationConfig(
    temperature=0.1,
    top_p=0.4,
    top_k=10,
    candidate_count=1,
    max_output_tokens=2048,
)
generative_multimodal_model = GenerativeModel("gemini-pro-vision")
response = generative_multimodal_model.generate_content([ *New, "Parse values of Date, open, high, low, close from EVERY ONE these images of financial data. provide data in a table."], generation_config=generation_config)
print(response.candidates[0].text)
# Out:
#  | Date         | Open  | High | Low | Close |
# |-------------|-------|-------|------|-------|
# | 12/22/2022   | 3843.34 | 3846.65 | 3812.22 | 3829.25 |
# | 12/23/2022   | 3829.56 | 3858.19 | 3780.78 | 3848.28 |
# | 12/27/2022   | 3836.29 | 3848.46 | 3793.44 | 3835.97 |
# | 12/28/2022   | 3855.74 | 3903.95 | 3847.62 | 3899.09 |
# | 12/29/2022   | 3910.82 | 4015.39 | 3926.59 | 3972.36 |
# | 12/30/2022   | 3972.71 | 4039.21 | 3957.64 | 4016.93 |
# | 1/3/2023     | 4053.72 | 4123.36 | 4034.06 | 4060.43 |
# | 1/4/2023     | 4085.85 | 4092.41 | 4020.44 | 4027.21 |
# | 1/5/2023     | 4020.23 | 4058.68 | 4013.23 | 4036.48 |
# | 1/6/2023     | 4095.44 | 4158.44 | 4091.55 | 4119.21 |

# %%
#multiple images per request [block-2]
New = images[:15]
generation_config = GenerationConfig(
    temperature=0.1,
    top_p=0.4,
    top_k=10,
    candidate_count=1,
    max_output_tokens=2048,
)
generative_multimodal_model = GenerativeModel("gemini-pro-vision")
response = generative_multimodal_model.generate_content([ *New, "Parse values of Date, open, high, low, close from EVERY ONE these images of financial data. provide data in a table."], generation_config=generation_config)
print(response.candidates[0].text)
# Out:
#  | Date         | Open  | High | Low | Close |
# |-------------|-------|-------|------|-------|
# | 12/22/2022   | 3843.34 | 3846.65 | 3812.22 | 3829.25 |
# | 12/23/2022   | 3829.56 | 3858.19 | 3780.78 | 3848.28 |
# | 12/27/2022   | 3836.29 | 3848.46 | 3793.44 | 3835.97 |
# | 12/28/2022   | 3855.74 | 3903.95 | 3847.62 | 3899.09 |
# | 12/29/2022   | 3910.82 | 4015.39 | 3926.59 | 3972.36 |
# | 12/30/2022   | 3972.71 | 4039.21 | 3957.64 | 4016.93 |
# | 1/3/2023     | 4053.72 | 4123.36 | 4034.06 | 4060.43 |
# | 1/4/2023     | 4085.85 | 4092.41 | 4020.44 | 4027.21 |
# | 1/5/2023     | 4020.23 | 4058.68 | 4013.23 | 4036.48 |
# | 1/6/2023     | 4095.44 | 4158.66 | 4080.78 | 4136.84 |

# %%
#multiple images per request [block-3]
New = images[:15]
generation_config = GenerationConfig(
    temperature=0.1,
    top_p=0.4,
    top_k=10,
    candidate_count=1,
    max_output_tokens=2048,
)
generative_multimodal_model = GenerativeModel("gemini-pro-vision")
response = generative_multimodal_model.generate_content([ *New, "Parse values of Date, open, high, low, close from EVERY ONE these images of financial data. provide data in a table."], generation_config=generation_config)
print(response.candidates[0].text)
# Out:
#  | Date         | Open  | High | Low | Close |
# |-------------|-------|-------|------|-------|
# | 12/22/2022   | 3843.34 | 3846.65 | 3812.22 | 3829.25 |
# | 12/23/2022   | 3829.56 | 3858.19 | 3780.78 | 3848.28 |
# | 12/27/2022   | 3836.29 | 3848.46 | 3793.44 | 3835.97 |
# | 12/28/2022   | 3855.74 | 3903.95 | 3847.62 | 3899.09 |
# | 12/29/2022   | 3910.82 | 4015.39 | 3926.59 | 3972.36 |
# | 12/30/2022   | 3972.71 | 4039.21 | 3957.64 | 4016.93 |
# | 1/3/2023     | 4053.72 | 4123.36 | 4034.06 | 4060.43 |
# | 1/4/2023     | 4085.85 | 4092.41 | 4020.44 | 4027.21 |
# | 1/5/2023     | 4020.23 | 4058.68 | 4013.23 | 4036.48 |
# | 1/6/2023     | 4095.44 | 4158.66 | 4080.76 | 4136.84 |

# %%
#multiple images per request [block-4]
New = images[:15]
generation_config = GenerationConfig(
    temperature=0.1,
    top_p=0.4,
    top_k=10,
    candidate_count=1,
    max_output_tokens=2048,
)
generative_multimodal_model = GenerativeModel("gemini-pro-vision")
response = generative_multimodal_model.generate_content([ *New, "Parse values of Date, open, high, low, close from EVERY ONE these images of financial data. provide data in a table."], generation_config=generation_config)
print(response.candidates[0].text)
# Out:
#  | Date         | Open  | High | Low  | Close |
# |-------------|-------|-------|-------|-------|
# | 12/22/2022   | 3834.36 | 3846.65 | 3812.22 | 3829.25 |
# | 12/23/2022   | 3829.56 | 3858.19 | 3780.78 | 3848.28 |
# | 12/27/2022   | 3855.29 | 3893.46 | 3794.33 | 3852.97 |
# | 12/28/2022   | 3836.08 | 3874.16 | 3802.42 | 3835.08 |
# | 12/29/2022   | 3839.74 | 3905.93 | 3824.12 | 3890.09 |
# | 12/30/2022   | 3910.82 | 3950.57 | 3897.29 | 3915.25 |
# | 1/3/2023     | 3906.6  | 4013.23 | 3896.54 | 3999.09 |
# | 1/4/2023     | 3988.28 | 4015.48 | 3926.59 | 3928.86 |
# | 1/5/2023     | 3911.84 | 3972.96 | 3885.54 | 3972.61 |
# | 1/6/2023     | 3978.14 | 4039.31 | 3957.64 | 4016.95 |
# | 1/9/2023     | 4032.71 | 4061.57 | 3949.06 | 4060.43 |
# | 1/10/2023    | 4055.72 | 4092.41 | 4015.55 | 4017.77 |
# | 1/11/2023    | 4020.85 | 4148.95 | 4020.44 | 4119.21 |
# | 1/12/2023    | 4158.68 | 4195.44 | 4123.36 | 4136.48 |

# %%
#multiple images per request [block-5]
New = images[:15]
generation_config = GenerationConfig(
    temperature=0.1,
    top_p=0.4,
    top_k=10,
    candidate_count=1,
    max_output_tokens=2048,
)
generative_multimodal_model = GenerativeModel("gemini-pro-vision")
response = generative_multimodal_model.generate_content([ *New, "Parse values of Date, open, high, low, close from EVERY ONE these images of financial data. provide data in a table."], generation_config=generation_config)
print(response.candidates[0].text)
# Out:
#  | Date         | Open  | High | Low | Close |
# |-------------|-------|-------|------|-------|
# | 12/22/2022   | 3843.34 | 3846.65 | 3812.22 | 3829.25 |
# | 12/23/2022   | 3829.56 | 3858.19 | 3780.78 | 3848.28 |
# | 12/27/2022   | 3836.29 | 3848.46 | 3793.44 | 3835.97 |
# | 12/28/2022   | 3855.74 | 3903.95 | 3847.62 | 3899.09 |
# | 12/29/2022   | 3910.82 | 4015.39 | 3926.59 | 3972.36 |
# | 12/30/2022   | 3972.71 | 4039.21 | 3957.64 | 4016.93 |
# | 1/3/2023     | 4053.72 | 4123.36 | 4034.06 | 4060.43 |
# | 1/4/2023     | 4085.85 | 4092.41 | 4020.44 | 4027.21 |
# | 1/5/2023     | 4020.23 | 4058.68 | 4013.23 | 4036.48 |
# | 1/6/2023     | 4095.44 | 4158.66 | 4080.76 | 4136.84 |

# %% [markdown]
# ## Parse the first 15 images 5 times to the model and concatenate all the outputs

# %%
# Initialize an empty list to store the outputs
all_outputs = []

# Execute the code block 5 times
for _ in range(5):
    New = images[:15]
    
    generation_config = GenerationConfig(
        temperature=0.1,
        top_p=0.4,
        top_k=10,
        candidate_count=1,
        max_output_tokens=2048,
    )
    
    generative_multimodal_model = GenerativeModel("gemini-pro-vision")
    response = generative_multimodal_model.generate_content([*New, "Parse values of Date, open, high, low, close from EVERY ONE of these images of financial data. provide data in a json table."], generation_config=generation_config)
    
    # Append the output to the list
    all_outputs.append(response.candidates[0].text)

# %%
# import json

# # Initialize an empty list to store the outputs
# all_outputs = []

# # Execute the code block 5 times
# for _ in range(5):
#     New = images[:15]
    
#     generation_config = GenerationConfig(
#         temperature=0.1,
#         top_p=0.4,
#         top_k=10,
#         candidate_count=1,
#         max_output_tokens=2048,
#     )
    
#     generative_multimodal_model = GenerativeModel("gemini-pro-vision")
#     response = generative_multimodal_model.generate_content([*New, "Parse values of Date, open, high, low, close from EVERY ONE of these images of financial data. provide data in a json table."], generation_config=generation_config)
    
#     # Extract relevant information from the response
#     output_data = {
#         "iteration": _ + 1,
#         "generated_text": response.candidates[0].text,
#     }
    
#     # Append the output to the list
#     all_outputs.append(output_data)

# # Convert the list of dictionaries to a JSON-formatted string
# concatenated_json = json.dumps(all_outputs, indent=2)

# # Print the concatenated JSON
# print(concatenated_json)

# %%
# Assuming 'all_outputs' is the list containing the outputs from the previous code
# ...

# Concatenate the responses into a single string
concatenated_json = '\n'.join(all_outputs)

# Now 'concatenated_response' contains the combined text of all 5 responses
print(concatenated_json)
# Out:
#  ```json
# [
#   {
#     "Date": "12/22/22",
#     "Open": "3834.36",
#     "High": "3846.65",
#     "Low": "3812.32",
#     "Close": "3829.25"
#   },
#   {
#     "Date": "12/23/22",
#     "Open": "3829.56",
#     "High": "3858.19",
#     "Low": "3780.78",
#     "Close": "3848.28"
#   },
#   {
#     "Date": "12/27/22",
#     "Open": "3855.29",
#     "High": "3905.93",
#     "Low": "3847.64",
#     "Close": "3899.09"
#   },
#   {
#     "Date": "12/28/22",
#     "Open": "3914.84",
#     "High": "3972.96",
#     "Low": "3926.59",
#     "Close": "3972.61"
#   },
#   {
#     "Date": "12/29/22",
#     "Open": "3978.21",
#     "High": "4015.35",
#     "Low": "3957.64",
#     "Close": "4016.95"
#   },
#   {
#     "Date": "12/30/22",
#     "Open": "4032.72",
#     "High": "4061.57",
#     "Low": "4017.77",
#     "Close": "4053.77"
#   },
#   {
#     "Date": "1/3/23",
#     "Open": "4055.72",
#     "High": "4092.41",
#     "Low": "4020.44",
#     "Close": "4119.21"
#   },
#   {
#     "Date": "1/4/23",
#     "Open": "4158.68",
#     "High": "4195.44",
#     "Low": "4123.36",
#     "Close": "4136.48"
#   }
# ]
# ```
#  ```json
# [
#   {
#     "Date": "12/22/22",
#     "Open": "3834.36",
#     "High": "3846.65",
#     "Low": "3812.32",
#     "Close": "3829.25"
#   },
#   {
#     "Date": "12/23/22",
#     "Open": "3829.56",
#     "High": "3858.19",
#     "Low": "3780.78",
#     "Close": "3848.28"
#     "High": "4015.35",
#     "Low": "3957.64",
#     "Close": "4016.95"
#   },
#   {
#     "Date": "12/30/22",
#     "Open": "4032.72",
#     "High": "4061.57",
#     "Low": "3949.06",
#     "Close": "4060.43"
#   },
#   {
#     "Date": "1/3/23",
#     "Open": "4055.72",
#     "High": "4092.41",
#     "Low": "4015.55",
#     "Close": "4017.77"
#   },
#   {
#     "Date": "1/4/23",
#     "Open": "4020.85",
#     "High": "4148.95",
#     "Low": "4020.44",
#     "Close": "4119.21"
#   },
#   {
#     "Date": "1/5/23",
#     "Open": "4158.68",
#     "High": "4195.44",
#     "Low": "4123.36",
#     "Close": "4136.48"
#   }
# ]
# ```
#  ```json
# [
#   {
#     "Date": "12/22/22",
#     "Open": "3834.36",
#     "High": "3846.65",
#     "Low": "3812.32",
#     "Close": "3829.25"
#   },
#   {
#     "Date": "12/23/22",
#     "Open": "3829.56",
#     "High": "3858.19",
#     "Low": "3780.78",
#     "Close": "3848.28"
#   },
#   {
#     "Date": "12/27/22",
#     "Open": "3855.29",
#     "High": "3905.93",
#     "Low": "3847.64",
#     "Close": "3899.09"
#   },
#   {
#     "Date": "12/28/22",
#     "Open": "3914.84",
#     "High": "3972.96",
#     "Low": "3926.59",
#     "Close": "3972.61"
#   },
#   {
#     "Date": "12/29/22",
#     "Open": "3978.21",
#     "High": "4015.35",
#     "Low": "3957.64",
#     "Close": "4016.95"
#   },
#   {
#     "Date": "12/30/22",
#     "Open": "4032.72",
#     "High": "4061.57",
#     "Low": "4017.77",
#     "Close": "4053.77"
#   },
#   {
#     "Date": "1/3/23",
#     "Open": "4055.72",
#     "High": "4092.41",
#     "Low": "4020.44",
#     "Close": "4119.21"
#   },
#   {
#     "Date": "1/4/23",
#     "Open": "4158.68",
#     "High": "4195.44",
#     "Low": "4123.36",
#     "Close": "4136.48"
#   }
# ]
# ```

# %% [markdown]
# ## Grouped and averaged data from the 5 responses

# %%
import json
import re

# Extract JSON content from concatenated_json using regular expression
json_pattern = r'```json(.+?)```'
match = re.search(json_pattern, concatenated_json, re.DOTALL)

if match:
    json_content = match.group(1).strip()
    # Parse the extracted JSON data
    combined_data = json.loads(json_content)

    # Group and average
    result = group_and_average(combined_data)
    
    answer = json.dumps(result, indent=2)

    # Print the result
    print(answer)
else:
    print("No JSON content found in the input.")
# Out:
# [
#   {
#     "Date": "12/22/22",
#     "Open": 3834.36,
#     "High": 3846.65,
#     "Low": 3812.32,
#     "Close": 3829.25
#   },
#   {
#     "Date": "12/23/22",
#     "Open": 3829.56,
#     "High": 3858.19,
#     "Low": 3780.78,
#     "Close": 3848.28
#   },
#   {
#     "Date": "12/27/22",
#     "Open": 3855.29,
#     "High": 3905.93,
#     "Low": 3847.64,
#     "Close": 3899.09
#   },
#   {
#     "Date": "12/28/22",
#     "Open": 3914.84,
#     "High": 3972.96,
#     "Low": 3926.59,
#     "Close": 3972.61
#   },
#   {
#     "Date": "12/29/22",
#     "Open": 3978.21,
#     "High": 4015.35,
#     "Low": 3957.64,
#     "Close": 4016.95
#   },
#   {
#     "Date": "12/30/22",
#     "Open": 4032.72,
#     "High": 4061.57,
#     "Low": 4017.77,
#     "Close": 4053.77
#   },
#   {
#     "Date": "1/3/23",
#     "Open": 4055.72,
#     "High": 4092.41,
#     "Low": 4020.44,
#     "Close": 4119.21
#   },
#   {
#     "Date": "1/4/23",
#     "Open": 4158.68,
#     "High": 4195.44,
#     "Low": 4123.36,
#     "Close": 4136.48
#   }
# ]

# %%
# #multiple images per request running 5 times
# images_to_parse = images[:15] * 5  # Repeat the first 15 images 5 times

# generation_config = GenerationConfig(
#     temperature=0.1,
#     top_p=0.4,
#     top_k=10,
#     candidate_count=1,
#     max_output_tokens=2048,
# )

# generative_multimodal_model = GenerativeModel("gemini-pro-vision")

# parsed_data = []

# for image in images_to_parse:
#     response = generative_multimodal_model.generate_content([image, "Parse values of Date, open, high, low, close from EVERY ONE of these images of financial data. Provide data in a table."], generation_config=generation_config)
#     parsed_data.append(response.candidates[0].text)

# # Print or use parsed_data as needed
# for i, data in enumerate(parsed_data):
#     print(f"Data from Image {i + 1}:\n{data}\n")
# Out:
# Data from Image 1:
#  | Date      | Open | High | Low | Close |
# | :---:        |    :----:   |    :----:   |    :----:   |    :----:   |
# | 12/26/22 | 3843.34 | 3846.65 | 3813.22 | 3829.25 |
# | 12/27/22 | 3834.23 | 3862.78 | 3825.43 | 3850.91 |
# | 12/28/22 | 3840.23 | 3851.32 | 3823.45 | 3832.87 |
# | 12/29/22 | 3838.23 | 3851.32 | 3823.45 | 3832.87 |
# | 12/30/22 | 3838.23 | 3851.32 | 3823.45 | 3832.87 |
#
# Data from Image 2:
#  | Date      | Open  | High | Low  | Close |
# | :---:        |    :----:   |    :----:   |   :----:  |   :----:  |
# | 12/28/22 | 3829.56 | 3858.19 | 3780.78 | 3849.28 |
# | 12/27/22 | 3764.75 | 3803.97 | 3754.63 | 3785.26 |
# | 12/22/22 | 3735.12 | 3775.34 | 3716.23 | 3754.64 |
# | 12/21/22 | 3692.94 | 3754.80 | 3686.81 | 3735.13 |
# | 12/20/22 | 3630.27 | 3695.22 | 3623.46 | 3692.95 |
#
# Data from Image 3:
#  | Date       | Open  | High  | Low | Close |
# |------------|-------|-------|------|-------|
# | 12/30/2022 | 3829.06 | 3839.85 | 3800.24 | 3838.95 |
# | 12/29/2022 | 3835.58 | 3862.94 | 3823.51 | 3850.81 |
# | 12/28/2022 | 3840.82 | 3851.34 | 3820.12 | 3825.67 |
# | 12/27/2022 | 3809.22 | 3845.98 | 3805.67 | 3833.12 |
# | 12/26/2022 | 3779.36 | 3816.32 | 3769.72 | 3808.13 |
#
# Data from Image 4:
#  | Date    | Open  | High | Low  | Close |
# | ------- | ----- | ----- | ---- | ----- |
# | 1/3/23  | 3855.29 | 3878.46 | 3794.33 | 3852.97 |
# | 12/30/22 | 3789.44 | 3823.86 | 3767.22 | 3809.52 |
# | 12/29/22 | 3734.26 | 3797.42 | 3725.63 | 3789.44 |
# | 12/28/22 | 3692.74 | 3755.14 | 3686.23 | 3734.26 |
# | 12/27/22 | 3661.87 | 3713.21 | 3648.92 | 3692.74 |
#
# Data from Image 5:
#  | Date      | Open  | High | Low | Close |
# | :---:        |    :----:   |    :----:   |   :----:  |    :----:   |
# | 1

#  | Date      | Open  | High | Low  | Close |
# | :---:        |    :----:   |    :----:   |   :----:  |   :----:  |
# | 2/23/23 | 4158.68 | 4195.44 | 4123.36 | 4136.48 |

# %%
# # Each 15 times running 5 times
# images_to_parse = images[:15]

# generation_config = GenerationConfig(
#     temperature=0.1,
#     top_p=0.4,
#     top_k=10,
#     candidate_count=1,
#     max_output_tokens=2048,
# )

# generative_multimodal_model = GenerativeModel("gemini-pro-vision")

# parsed_data = []

# for i, image in enumerate(images_to_parse * 5):  # Repeat each image 5 times
#     response = generative_multimodal_model.generate_content([image, f"Parse values of Date, open, high, low, close from Image {i + 1} of financial data. Provide data in a table."], generation_config=generation_config)
#     parsed_data.append(response.candidates[0].text)

# # Print or use parsed_data as needed
# for i, data in enumerate(parsed_data):
#     print(f"Data from Image {i + 1}:\n{data}\n")
# Out:
# Data from Image 1:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 12/26/22 | 3843.34 | 3846.65 | 3813.22 | 3829.25 |
#
# Data from Image 2:
#  | Date      | Open  | High | Low  | Close |
# | :---:        |    :----:   |    :----:   |   :----:  |    :----:   |
# | 12/28/22 | 3829.56 | 3858.19  |  3780.78 | 3849.28 |
#
# Data from Image 3:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 12/30/22 | 3829.06 | 3839.85 | 3800.24 | 3839.5 |
#
# Data from Image 4:
#  | Date      | Open  | High | Low  | Close |
# | :---:        |    :----:   |    :----:   |   :----:  |    :----:   |
# | 1/3/2023   | 3855.29 | 3878.46  |  3794.33 | 3852.97 |
#
# Data from Image 5:
#  | Date      | Open  | High | Low  | Close |
# | :---:        |    :----:   |    :----:   |   :----:  |    :----:   |
# | 1/5/23   | 3839.74 | 3906.19 | 3802.42 | 3895.08 |
#
# Data from Image 6:
#  | Date      | Open  | High | Low | Close |
# | :---:        |    :----:   |    :----:   |   :----:  |    :----:   |
# | 19/9/23   | 3910.82 | 3950.57 | 3877.29 | 3919.25 |
#
# Data from Image 7:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 11/17/23 | 3932.35 | 3997.76 | 3928.54 | 3983.17 |
# | 11/18/23 | 3935.87 | 3956.23 | 3910.23 | 3922.36 |
# | 11/20/23 | 3938.23 | 3955.67 | 3920.12 | 3930.87 |
# | 11/21/23 | 3955.23 | 3965.32 | 3930.23 | 3950.23 |
# | 11/22/23 | 3960.34 | 3975.34 | 3945.23 | 3955.34 |
#
# Data from Image 8:
#  | Date      | Open  | High | Low  | Close |
# | :---:        |    :----:   |    :----:   |   :----:  |    :----:   |
# | 12/31/2022   | 3960.64 | 4003.95 | 3947.67 | 3999.09 |
#
# Data from Image 9:
#  | Date | Open | High | Low | Close |
# |---|---|---|---|---|
# | 1/17/23 | 3999.28 | 4015.39 | 3926.59 | 3928.86 |
#
# Data from Image 10:
#  | Date      | Open  | High | Low  | Close |
# | :---:        |    :----:   |    :----:   |   :----:  |    :----:   |
# | 1/19/23   | 3911.84 | 3972.96 | 3885.54 | 3972.61 |
#
# Data from Image 11:
#  | Date      | Open  | High | Low  | Close |
# | :---:        |    :----:   |    :----:   |   :----:  |    :----:   |
# | 1/23/23 | 3978.14 | 4039.31 | 3971.64 | 4016.95 |
#
# Data from Image 12:
#  | Date      | Open  | High | Low  | Close |
# | :---:        |    :----:   |    :----:   |   :----:  |    :----:   |
# | 12/25/2023 | 3982.71 | 4061.57 | 3949.06 | 4060.43 |
#
# Data from Image 13:
#  | Date | Open | High | Low | Close |
# |---|---|---|---|---|
# | 1/27/23 | 4053.72 | 4094.21 | 4015.55 | 4017.77 |
#
# Data from Image 14:
#  | Date      | Open | High | Low | Close |
# | :---:        |    :----:   |    :----:   |    :----:   |    :----:   |
# | 1/3/2023 | 4020.85 | 4148.95 | 4020.44 | 4119.21 |
#
# Data from Image 15:
#  | Date | Open | High | Low | Close |
# | :---: | :---: | :---: | :---: | :---: |
# | 2/23/23 | 4158.68 | 4195.44 | 4123.36 | 4136.48 |
#
# Data from Image 16:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 12/26/22 | 3843.34 | 3846.65 | 3813.22 | 3829.25 |
#
# Data from Image 17:
#  | Date      | Open  | High | Low  | Close |
# | :---:        |    :----:   |    :----:   |   :----:  |   :----:   |
# | 12/28/22 | 3829.56 | 3858.19  |  3780.78 | 3849.28 |
#
# Data from Image 18:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 12/30/22 | 3829.06 | 3839.85 | 3800.24 | 3839.5 |
#
# Data from Image 19:
#  | Date | Open | High | Low | Close |
# | :---: | :---: | :---: | :---: | :---: |
# | 1/3/23 | 3855.29 | 3878.46 | 3794.33 | 3852.97 |
#
# Data from Image 20:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 1/5/23 | 3839.74 | 3906.19 | 3802.42 | 3895.08 |
#
# Data from Image 21:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 19/9/23 | 3910.82 | 3950.57 | 3877.29 | 3919.25 |
#
# Data from Image 22:
#  | Date | Open | High | Low | Close |
# |---|---|---|---|---|
# | 11/23/23 | 3932.35 | 3997.76 | 3928.54 | 3983.17 |
#
# Data from Image 23:
#  | Date | Open | High | Low | Close |
# | ------ | ------ | ------ | ------ | ------ |
# | 1/13/23 | 3960.64 | 4003.95 | 3947.67 | 3999.09 |
#
# Data from Image 24:
#  | Date | Open | High | Low | Close |
# |---|---|---|---|---|
# | 1/17/23 | 3999.28 | 4015.39 | 3926.59 | 3928.86 |
#
# Data from Image 25:
#  | Date         | Open  | High | Low  | Close |
# |--------------|-------|-------|-------|-------|
# | 1/19/2023   | 3911.84 | 3972.96 | 3885.54 | 3972.61 |
# | 1/20/2023   | 3958.03 | 4015.87 | 3945.94 | 4009.27 |
# | 1/23/2023   | 4015.52 | 4065.27 | 4000.00 | 4032.93 |
# | 1/24/2023   | 4023.81 | 4086.25 | 4010.00 | 4079.78 |
# | 1/25/2023   | 4069.34 | 4126.51 | 4055.00 | 4089.12 |
# | 1/26/2023   | 4075.81 | 4105.00 | 4050.01 | 4055.62 |
# | 1/27/2023   | 4045.81 | 4080.00 | 4020.12 | 4058.21 |
#
# Data from Image 26:
#  | Date | Open | High | Low | Close |
# | :---: | :---: | :---: | :---: | :---: |
# | 1/23/23 | 3978.14 | 4039.31 | 3971.64 | 4016.95 |
#
# Data from Image 27:
#  | Date | Open | High | Low | Close |
# | :---: | :---: | :---: | :---: | :---: |
# | 12/23/23 | 3982.71 | 4061.57 | 3949.06 | 4060.43 |
#
# Data from Image 28:
#  | Date | Open | High | Low | Close |
# |---|---|---|---|---|
# | 1/27/23 | 4053.72 | 4094.21 | 4015.55 | 4017.77 |
#
# Data from Image 29:
#  | Date      | Open | High | Low | Close |
# | :---:        |    :----:   |    :----:   |    :----:   |    :----:   |
# | 1/3/2023 | 4020.85 | 4148.95 | 4020.44 | 4119.21 |
#
# Data from Image 30:
#  | Date | Open | High | Low | Close |
# | :---: | :---: | :---: | :---: | :---: |
# | 2/23/23 | 4158.68 | 4195.44 | 4123.36 | 4136.48 |
#
# Data from Image 31:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 12/26/22 | 3843.34 | 3846.65 | 3813.22 | 3829.25 |
#
# Data from Image 32:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 12/28/22 | 3829.56 | 3858.19 | 3780.78 | 3849.28 |
#
# Data from Image 33:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 12/30/22 | 3829.06 | 3839.85 | 3800.24 | 3839.5 |
#
# Data from Image 34:
#  | Date | Open | High | Low | Close |
# | :---: | :---: | :---: | :---: | :---: |
# | 1/3/23 | 3855.29 | 3878.46 | 3794.33 | 3852.97 |
#
# Data from Image 35:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 1/5/23 | 3839.74 | 3906.19 | 3802.42 | 3895.08 |
#
# Data from Image 36:
#  | Date      | Open  | High | Low  | Close |
# | :---:        |    :----:   |    :----:   |   :----:  |   :----:  |
# | 19/9/23   | 3910.82 | 3950.57 | 3877.29 | 3919.25 |
#
# Data from Image 37:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 11/17/23 | 3932.35 | 3997.76 | 3928.54 | 3983.17 |
# | 11/18/23 | 3935.87 | 3956.23 | 3910.23 | 3922.36 |
# | 11/20/23 | 3935.23 | 3955.65 | 3910.22 | 3922.36 |
# | 11/21/23 | 3955.23 | 3990.23 | 3935.23 | 3980.12 |
# | 11/22/23 | 3980.23 | 4012.23 | 3965.23 | 4000.23 |
#
# Data from Image 38:
#  | Date | Open | High | Low | Close |
# | :---: | :---: | :---: | :---: | :---: |
# | 1/13/23 | 3960.60 | 4003.95 | 3947.67 | 3999.09 |
#
# Data from Image 39:
#  | Date | Open | High | Low | Close |
# |---|---|---|---|---|
# | 1/17/23 | 3999.28 | 4015.39 | 3926.59 | 3928.86 |
#
# Data from Image 40:
#  | Date      | Open  | High | Low  | Close |
# | :---:        |    :----:   |    :----:   |   :----:  |    :----:   |
# | 1/19/23   | 3911.84 | 3972.96 | 3885.54 | 3972.61 |
#
# Data from Image 41:
#  | Date      | Open  | High | Low  | Close |
# | :---:        |    :----:   |    :----:   |   :----:  |    :----:   |
# | 1/23/23 | 3978.14 | 4039.31 | 3971.64 | 4016.95 |
#
# Data from Image 42:
#  | Date | Open | High | Low | Close |
# | :---: | :---: | :---: | :---: | :---: |
# | 12/23/23 | 3982.71 | 4061.57 | 3949.06 | 4060.43 |
#
# Data from Image 43:
#  | Date | Open | High | Low | Close |
# |---|---|---|---|---|
# | 1/27/23 | 4053.72 | 4094.21 | 4015.55 | 4017.77 |
#
# Data from Image 44:
#  | Date      | Open | High | Low | Close |
# | :---:        |    :----:   |    :----:   |    :----:   |    :----:   |
# | 1/3/2023 | 4020.85 | 4148.95 | 4020.44 | 4119.21 |
#
# Data from Image 45:
#  | Date | Open | High | Low | Close |
# | :---: | :---: | :---: | :---: | :---: |
# | 2/23/23 | 4158.68 | 4195.44 | 4123.36 | 4136.48 |
#
# Data from Image 46:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 12/26/22 | 3843.34 | 3846.65 | 3813.22 | 3829.25 |
#
# Data from Image 47:
#  | Date      | Open  | High | Low  | Close |
# | :---:        |    :----:   |    :----:   |   :----:  |    :----:   |
# | 12/28/22 | 3829.56 | 3858.19 | 3780.78 | 3849.28 |
#
# Data from Image 48:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 12/30/22 | 3829.06 | 3839.85 | 3800.24 | 3839.5 |
#
# Data from Image 49:
#  | Date | Open | High | Low | Close |
# | :---: | :---: | :---: | :---: | :---: |
# | 1/3/23 | 3855.29 | 3878.46 | 3794.33 | 3852.97 |
#
# Data from Image 50:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 1/5/23 | 3839.74 | 3906.19 | 3802.42 | 3895.08 |
#
# Data from Image 51:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 19/9/23 | 3910.82 | 3950.57 | 3877.29 | 3919.25 |
#
# Data from Image 52:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 11/17/23 | 3932.35 | 3997.76 | 3928.54 | 3983.17 |
# | 11/18/23 | 3935.87 | 3952.98 | 3910.23 | 3922.12 |
#
# Data from Image 53:
#  | Date | Open | High | Low | Close |
# | :---: | :---: | :---: | :---: | :---: |
# | 1/13/23 | 3960.60 | 4003.95 | 3947.67 | 3999.09 |
#
# Data from Image 54:
#  | Date | Open | High | Low | Close |
# |---|---|---|---|---|
# | 1/17/23 | 3999.28 | 4015.39 | 3926.59 | 3928.86 |
#
# Data from Image 55:
#  | Date      | Open  | High | Low  | Close |
# | :---:        |    :----:   |    :----:   |   :----:  |    :----:   |
# | 1/19/23   | 3911.84 | 3972.96 | 3885.54 | 3972.61 |
#
# Data from Image 56:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 1/23/23 | 3978.14 | 4039.31 | 3971.64 | 4016.95 |
#
# Data from Image 57:
#  | Date | Open | High | Low | Close |
# | :---: | :---: | :---: | :---: | :---: |
# | 12/25/23 | 3982.71 | 4061.57 | 3949.06 | 4060.43 |
#
# Data from Image 58:
#  | Date | Open | High | Low | Close |
# |---|---|---|---|---|
# | 1/27/23 | 4053.72 | 4094.21 | 4015.55 | 4017.77 |
#
# Data from Image 59:
#  | Date      | Open  | High | Low  | Close |
# | :---:        |    :----:   |    :----:   |   :----:  |    :----:   |
# | 1/3/2023   | 4020.85 | 4148.95 | 4020.44 | 4119.21 |
#
# Data from Image 60:
#  | Date | Open | High | Low | Close |
# | :---: | :---: | :---: | :---: | :---: |
# | 2/23/23 | 4158.68 | 4195.44 | 4123.36 | 4136.48 |
#
# Data from Image 61:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 12/26/22 | 3843.34 | 3846.65 | 3813.22 | 3829.25 |
#
# Data from Image 62:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 12/28/22 | 3829.56 | 3858.19 | 3780.78 | 3849.28 |
#
# Data from Image 63:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 12/30/22 | 3829.06 | 3839.85 | 3800.24 | 3839.5 |
#
# Data from Image 64:
#  | Date | Open | High | Low | Close |
# | :---: | :---: | :---: | :---: | :---: |
# | 1/3/23 | 3855.29 | 3878.46 | 3794.33 | 3852.97 |
#
# Data from Image 65:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 1/5/23 | 3839.74 | 3906.19 | 3802.42 | 3895.08 |
#
# Data from Image 66:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 19/9/23 | 3910.82 | 3950.57 | 3877.29 | 3919.25 |
#
# Data from Image 67:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 11/17/23 | 3932.35 | 3997.76 | 3928.54 | 3983.17 |
# | 11/18/23 | 3935.87 | 3956.23 | 3910.23 | 3922.89 |
# | 11/20/23 | 3935.23 | 3955.65 | 3910.24 | 3922.33 |
# | 11/21/23 | 3955.23 | 3990.23 | 3930.23 | 3980.23 |
# | 11/22/23 | 3980.23 | 4010.23 | 3960.23 | 4000.23 |
#
# Data from Image 68:
#  | Date | Open | High | Low | Close |
# | ------ | ------ | ------ | ------ | ------ |
# | 1/13/23 | 3960.64 | 4003.95 | 3947.67 | 3999.09 |
#
# Data from Image 69:
#  | Date | Open | High | Low | Close |
# |---|---|---|---|---|
# | 1/17/23 | 3999.28 | 4015.39 | 3926.59 | 3928.86 |
#
# Data from Image 70:
#  | Date | Open | High | Low | Close |
# |---|---|---|---|---|
# | 1/19/23 | 3911.84 | 3972.96 | 3885.54 | 3972.61 |
#
# Data from Image 71:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 1/23/23 | 3978.14 | 4039.31 | 3971.64 | 4016.95 |
#
# Data from Image 72:
#  | Date | Open | High | Low | Close |
# | :---: | :---: | :---: | :---: | :---: |
# | 12/25/23 | 3982.71 | 4061.57 | 3949.06 | 4060.43 |
#
# Data from Image 73:
#  | Date | Open | High | Low | Close |
# |---|---|---|---|---|
# | 1/27/23 | 4053.72 | 4094.21 | 4015.55 | 4017.77 |
#
# Data from Image 74:
#  | Date | Open | High | Low | Close |
# | ---- | ---- | ---- | ---- | ---- |
# | 1/3/23 | 4020.85 | 4148.95 | 4020.44 | 4119.21 |
#
# Data from Image 75:
#  | Date | Open | High | Low | Close |
# | :---: | :---: | :---: | :---: | :---: |
# | 2/23/23 | 4158.68 | 4195.44 | 4123.36 | 4136.48 |

# %%
# #one image per repuest
# import time
# for image in New:
#     response = generative_multimodal_model.generate_content([*New,"parse date, open, high, low, close from this image and make a table", image])
#     print(response.candidates[0].text)
#     time.sleep(10)

# %%
# #video preprocessing
# import base64

# def convert_video_to_base64(video_file_path):
#     # Read the video file
#     with open(video_file_path, 'rb') as video_file:
#         video_data = video_file.read()

#     # Encode the video data in base64
#     base64_encoded_data = base64.b64encode(video_data)

#     # Convert to a string for easier handling
#     base64_encoded_string = base64_encoded_data.decode('utf-8')

#     return base64_encoded_string

# # Example usage
# video_base64 = convert_video_to_base64('C:/Users/SUYASH/Downloads/downloaded_video.mp4') #replace video location here

# %%
# prompt = """
# parse all the readings of date, open, high, low, close present in this video for the forst 15 frames. Provide this data in a table
# """
# generation_config={
#         "max_output_tokens": 2048,
#         "temperature": 0.4,
#         "top_p": 1,
#         "top_k": 32
#     }
# video = Part.from_data(
#     data=video_base64,
#     mime_type="video/mp4",
# )
# contents = [prompt, video]

# responses = multimodal_model.generate_content(contents, stream=True)


# print("\n-------Response--------")
# for response in responses:
#     print(response.text, end="")
# Out:
# -------Response--------
#  | Date | Open | High | Low | Close |
# |---|---|---|---|---|
# | 2023-03-08 | 3846.65 | 4126.43 | 4078.96 | 4096.12 |
# | 2023-03-09 | 4126.43 | 4439.56 | 4098.72 | 4420.11 |
# | 2023-03-10 | 4439.56 | 4510.33 | 4367.12 | 4390.24 |
# | 2023-03-13 | 4510.33 | 4772.94 | 4490.24 | 4737.87 |
# | 2023-03-14 | 4772.94 | 4850.24 | 4758.99 | 4810.24 |
# | 2023-03-15 | 4850.24 | 4920.33 | 4810.24 | 4888.99 |
# | 2023-03-16 | 4920.33 | 4988.99 | 4880.12 | 4930.23 |
# | 2023-03-17 | 4988.99 | 5050.22 | 4930.23 | 4990.23 |
# | 2023-03-20 | 5050.22 | 5120.33 | 4980.99 | 5080.33 |
# | 2023-03-21 | 5120.33 | 5190.22 | 5080.33 | 5140.23 |
# | 2023-03-22 | 5190.22 | 5260.34 | 5130.23 | 5200.23 |
# | 2023-03-23 | 5260.34 | 5330.23 | 5200.23 | 5270.33 |
# | 2023-03-24 | 5330.23 | 5400.33 | 5260.23 | 5340.22 |
# | 2023-03-27 | 5400.33 | 5470.23 | 5330.23 | 5390.23 |
# | 2023-03-28 | 5470.23 | 5540.32 | 5380.23 | 5450.23 |

# %% [markdown]
# ## Accuracy for previous unchanged model

# %%
# Sample data (replace it with your actual data)
actual_values = {
    "Date": ["12/28/22", "01-03-2023", "01-05-2023", "01-09-2023", "01-11-2023"],
    "Open": [3829.56, 3853.29, 3839.74, 3910.82, 3932.35],
    "High": [3858.19, 3878.46, 3906.19, 3950.57, 3997.76],
    "Low": [3780.78, 3794.33, 3802.42, 3877.29, 3928.54],
    "Close": [3849.28, 3852.97, 3895.08, 3919.25, 3983.17]
}

predicted_values = {
    "Date": ["12/22/2022", "12/23/2022", "01-05-2023", "01-09-2023", "01-11-2023"],
    "Open": [3836.08, 3855.29, 3839.74, 3910.82, 3932.35],
    "High": [3874.16, 3893.46, 3905.93, 3950.57, 3997.76],
    "Low": [3802.42, 3794.33, 3824.12, 3897.29, 3957.64],
    "Close": [3835.08, 3852.97, 3890.09, 3915.25, 3982.86]
}

# Calculate accuracy rate for each parameter
def calculate_accuracy_rate(actual, predicted):
    correct_predictions = sum([1 for a, p in zip(actual, predicted) if a == p])
    total_predictions = len(actual)
    accuracy_rate = (correct_predictions / total_predictions) * 100
    return accuracy_rate

# Calculate accuracy rates for Open, High, Low, and Close
accuracy_open = calculate_accuracy_rate(actual_values["Open"], predicted_values["Open"])
accuracy_high = calculate_accuracy_rate(actual_values["High"], predicted_values["High"])
accuracy_low = calculate_accuracy_rate(actual_values["Low"], predicted_values["Low"])
accuracy_close = calculate_accuracy_rate(actual_values["Close"], predicted_values["Close"])

# Calculate overall accuracy rate
overall_accuracy = (accuracy_open + accuracy_high + accuracy_low + accuracy_close) / 4

# Print the results
print(f"Accuracy Rate for Open: {accuracy_open:.2f}%")
print(f"Accuracy Rate for High: {accuracy_high:.2f}%")
print(f"Accuracy Rate for Low: {accuracy_low:.2f}%")
print(f"Accuracy Rate for Close: {accuracy_close:.2f}%")
print(f"Overall Accuracy Rate: {overall_accuracy:.2f}%")
# Out:
# Accuracy Rate for Open: 60.00%
# Accuracy Rate for High: 40.00%
# Accuracy Rate for Low: 20.00%
# Accuracy Rate for Close: 20.00%
# Overall Accuracy Rate: 35.00%

# %% [markdown]
# ## Previous kpi code provided in the doc

# %%
# Creating dataframes from the dictionaries
true_df = pd.DataFrame(true_data)
llm_df = pd.DataFrame(llm_data)
# Since the dates do not match, we will ignore the date comparison and focus on the financial figures
# We need to ensure that the data is in the same order for comparison, so we'll sort by the date
true_df['Date'] = pd.to_datetime(true_df['Date'])
llm_df['Date'] = pd.to_datetime(llm_df['Date'])
# Aligning LLM response to the true response based on closest date
llm_aligned_df = pd.DataFrame()
# For each date in the true data, find the closest date in the LLM data
for index, row in true_df.iterrows():
    closest_llm_row = llm_df.iloc[(llm_df['Date'] - row['Date']).abs().argsort()[:1]]
    llm_aligned_df = llm_aligned_df.append(closest_llm_row)
# Reset index for proper alignment
llm_aligned_df = llm_aligned_df.reset_index(drop=True)
# Calculate the accuracy as 1 - (MAE of LLM response / range of true values)
# This gives a proportion of correct values within the range
accuracy = {}
error_rate = {}
for column in ['Open', 'High', 'Low', 'Close']:
    true_range = true_df[column].max() - true_df[column].min()
    mae = mean_absolute_error(true_df[column], llm_aligned_df[column])
    accuracy[column] = 1 - (mae / true_range)
    error_rate[column] = mae / true_range
accuracy, error_rate
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-a44a621c592f> in <module>
#       1 # Creating dataframes from the dictionaries
# ----> 2 true_df = pd.DataFrame(true_data)
#       3 llm_df = pd.DataFrame(llm_data)
#       4 # Since the dates do not match, we will ignore the date comparison and focus on the financial figures
#       5 # We need to ensure that the data is in the same order for comparison, so we'll sort by the date
#
# NameError: name 'true_data' is not defined

# %% [markdown]
# ## Code for measuring accurate accuracy based on prompting responses

# %%
# #ACTUAL CORRECT CODE FOR MEASURE
# import pandas as pd
# from sklearn.metrics import mean_absolute_error
# from io import StringIO

# # Read the true data from the CSV file
# csv_file_path = 'C:/Users/SUYASH/Downloads/processed_1Y2D (1).csv'
# true_df = pd.read_csv(csv_file_path)

# # Replace response data here
# data_str = """Date,Open,High,Low,Close
# 12/22/2022,3834.36,3846.65,3812.22,3829.25
# 12/23/2022,3829.56,3858.19,3780.78,3848.28
# 12/27/2022,3855.29,3893.46,3794.33,3852.97
# 12/28/2022,3836.08,3874.16,3802.42,3835.08
# 12/29/2022,3839.74,3905.93,3824.12,3890.09
# 12/30/2022,3910.82,3950.57,3897.29,3915.25
# 1/3/2023,3906.6,4013.23,3896.54,3999.09
# 1/4/2023,3928.28,4015.48,3926.59,3982.86
# 1/5/2023,3911.84,3972.96,3885.54,3927.61
# 1/6/2023,3978.14,4039.23,3957.64,4016.95
# 1/9/2023,4032.71,4061.57,3949.06,4060.43
# 1/10/2023,4055.72,4092.41,4015.55,4017.77
# 1/11/2023,4020.85,4148.95,4020.44,4119.21
# 1/12/2023,4158.68,4195.44,4123.36,4136.48
# """

# # Read the LLM data as a CSV file into a DataFrame
# llm_df = pd.read_csv(StringIO(data_str))

# # Convert 'Date' column to datetime format
# true_df['Date'] = pd.to_datetime(true_df['Date'])
# llm_df['Date'] = pd.to_datetime(llm_df['Date'])

# # Sort DataFrames based on the 'Date' column
# true_df = true_df.sort_values(by='Date')
# llm_df = llm_df.sort_values(by='Date')

# # Merge DataFrames based on the closest dates
# merged_df = pd.merge_asof(true_df, llm_df, on='Date')

# # Calculate the accuracy as 1 - (MAE of LLM response / range of true values)
# # This gives a proportion of correct values within the range
# accuracy = {}
# error_rate = {}
# for column in ['Open', 'High', 'Low', 'Close']:
#     true_range = merged_df[f'{column}_x'].max() - merged_df[f'{column}_x'].min()
#     mae = mean_absolute_error(merged_df[f'{column}_x'], merged_df[f'{column}_y'])
#     accuracy[column] = 1 - (mae / true_range)
#     error_rate[column] = mae / true_range

# # Display the results
# print(merged_df)
# print("Accuracy:", accuracy)

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error
import json

# Read the true data from the CSV file
csv_file_path = 'C:/Users/SUYASH/Downloads/processed_1Y2D (1).csv'
true_df = pd.read_csv(csv_file_path)

# Use the 'answer' variable directly
answer_data = json.loads(answer)

# Convert the answer to a DataFrame
llm_df = pd.DataFrame(answer_data)

# Convert 'Date' column to datetime format
true_df['Date'] = pd.to_datetime(true_df['Date'])
llm_df['Date'] = pd.to_datetime(llm_df['Date'])

# Sort DataFrames based on the 'Date' column
true_df = true_df.sort_values(by='Date')
llm_df = llm_df.sort_values(by='Date')

# Merge DataFrames based on the closest dates
merged_df = pd.merge_asof(true_df, llm_df, on='Date')

# Calculate the accuracy as 1 - (MAE of LLM response / range of true values)
# This gives a proportion of correct values within the range
accuracy = {}
error_rate = {}
for column in ['Open', 'High', 'Low', 'Close']:
    true_range = merged_df[f'{column}_x'].max() - merged_df[f'{column}_x'].min()
    mae = mean_absolute_error(merged_df[f'{column}_x'], merged_df[f'{column}_y'])
    accuracy[column] = 1 - (mae / true_range)
    error_rate[column] = mae / true_range

# Display the results
print(merged_df)
print("Accuracy:", accuracy)

overall_accuracy = sum(accuracy.values()) / len(accuracy)
print("Overall Accuracy:", overall_accuracy)
# Out:
#           Date   Open_x   High_x    Low_x  Close_x   Open_y   High_y    Low_y  \
# 0   2022-12-26  3829.25  3843.34  3846.65  3813.22  3829.56  3858.19  3780.78
# 1   2022-12-28  3849.28  3829.56  3858.19  3780.78  3914.84  3972.96  3926.59
# 2   2022-12-30  3839.50  3829.06  3839.85  3800.34  4032.72  4061.57  4017.77
# 3   2023-01-03  3852.97  3853.29  3878.46  3794.33  4055.72  4092.41  4020.44
# 4   2023-01-05  3895.08  3839.74  3906.19  3802.42  4158.68  4195.44  4123.36
# ..         ...      ...      ...      ...      ...      ...      ...      ...
# 127 2023-12-11  4643.70  4593.39  4643.93  4593.39  4158.68  4195.44  4123.36
# 128 2023-12-13  4719.55  4646.20  4738.57  4643.23  4158.68  4195.44  4123.36
# 129 2023-12-15  4740.56  4714.23  4749.52  4704.69  4158.68  4195.44  4123.36
# 130 2023-12-19  4698.35  4743.72  4778.01  4697.82  4158.68  4195.44  4123.36
# 131 2023-12-21  4754.63  4724.29  4772.94  4708.35  4158.68  4195.44  4123.36
#
#      Close_y
# 0    3848.28
# 1    3972.61
# 2    4053.77
# 3    4119.21
# 4    4136.48
# ..       ...
# 127  4136.48
# 128  4136.48
# 129  4136.48
# 130  4136.48
# 131  4136.48
#
# [132 rows x 9 columns]
# Accuracy: {'Open': 0.7800819908872818, 'High': 0.7864496262562211, 'Low': 0.7595774998643379, 'Close': 0.7773315972885816}
# Overall Accuracy: 0.7758601785741055

# %%
answer
# Out:
# '[\n  {\n    "Date": "12/22/22",\n    "Open": 3834.36,\n    "High": 3846.65,\n    "Low": 3812.32,\n    "Close": 3829.25\n  },\n  {\n    "Date": "12/23/22",\n    "Open": 3829.56,\n    "High": 3858.19,\n    "Low": 3780.78,\n    "Close": 3848.28\n  },\n  {\n    "Date": "12/27/22",\n    "Open": 3855.29,\n    "High": 3905.93,\n    "Low": 3847.64,\n    "Close": 3899.09\n  },\n  {\n    "Date": "12/28/22",\n    "Open": 3914.84,\n    "High": 3972.96,\n    "Low": 3926.59,\n    "Close": 3972.61\n  },\n  {\n    "Date": "12/29/22",\n    "Open": 3978.21,\n    "High": 4015.35,\n    "Low": 3957.64,\n    "Close": 4016.95\n  },\n  {\n    "Date": "12/30/22",\n    "Open": 4032.72,\n    "High": 4061.57,\n    "Low": 4017.77,\n    "Close": 4053.77\n  },\n  {\n    "Date": "1/3/23",\n    "Open": 4055.72,\n    "High": 4092.41,\n    "Low": 4020.44,\n    "Close": 4119.21\n  },\n  {\n    "Date": "1/4/23",\n    "Open": 4158.68,\n    "High": 4195.44,\n    "Low": 4123.36,\n    "Close": 4136.48\n  }\n]'
